# %% [markdown]
# # Set Your Money on FIRE
# Money and Investing 101 - How to become financially independent
#
# Learn the basic principles of Financial Independence Retire Early (FIRE). During the workshop we will play with compounding interest and retirement planning visualizations and discuss budgeting and investing strategies that can lead to your financial independence. Note: Instructor is NOT a certified financial planner.

# %%
from IPython.display import YouTubeVideo, display
from helper_functions.mentimeter import Mentimeter

# %%
#Mentimeter(vote = 'https://www.menti.com/alohp2v13yqh',
#           result ='https://www.mentimeter.com/app/presentation/al3bon1eofr38siunek3o1ykwqqkf18w'
#          ).show()

# %%
Mentimeter(result ='https://www.mentimeter.com/app/presentation/al3bon1eofr38siunek3o1ykwqqkf18w'
          ).show()
# Out:
# <div style='width:100%; height:40vh;'> <iframe src=https://www.mentimeter.com/app/presentation/al3bon1eofr38siunek3o1ykwqqkf18w height=100% width=90%></iframe> </div>

# %% [markdown]
# # FIRE Overview

# %%
#a 5 minute overview of FIRE
YouTubeVideo('8si7cqw9wm0')

# %% [markdown]
# # How to become financially independent
#
# 1. Track your spending
# 2. Lower your spending and payoff debts
# 3. Invest
# 4. Retire early and only work when you want on things you are passionate about

# %% [markdown]
# <br>
#
# ----------
# <br>

# %% [markdown]
# # Why should you trust me or any other financial advisor for that matter?
#
# ## You shouldn't trust me
# - Ask lots of questions before giving money to someone else
# - Here is my financial story

# %% [markdown]
# <br>
#
# ----------
# <br>
